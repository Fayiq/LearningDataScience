# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
# type your code here
df = pd.read_csv('adult.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize = (10,7),dpi = 100)
sns.lineplot(df['age'],df['hours.per.week'],markers = '-')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df.groupby('education')['capital.gain'].mean()
plt.figure(figsize = (7,5))
x.sort_values().plot(kind = 'bar')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize = (7,5),dpi = 100)
sns.jointplot(x = 'hours.per.week',y='capital.gain',data = df)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.groupby('age')['hours.per.week'].mean().plot(kind = 'line')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x8 = df.groupby('age')['capital.loss'].mean()
plt.figure(figsize = (7,4),dpi = 100)
x8.plot(kind = 'line', x = 'age', y = 'avg_capital_loss')
plt.legend()
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize = (7,5),dpi = 100)

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x2 = df.groupby('income')['age'].mean()
plt.figure(figsize = (10,7),dpi = 100)
x2.plot(kind = 'bar')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize = (10,7),dpi = 100)
sns.violinplot(df['hours.per.week'],(df['sex']))
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(df['education'],df['income']).plot(kind='bar')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
print(df.groupby('sex')['age'].mean())
df.groupby('sex')['age'].mean().plot(kind = 'bar')
plt.show()
# Out:
# sex
# Female    36.858230
# Male      39.433547
# Name: age, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize = (10,7),dpi = 100)
sns.violinplot(df['income'],df['hours.per.week'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize = (10,7),dpi = 100)
sns.violinplot(df['sex'],df['age'], hue = df['race'])
plt.show()

# %%
plt.figure(figsize = (7,5),dpi = 100)
sns.violinplot(df['race'],df['age'], hue = df['sex'],split = True)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(10,10),dpi=100)
sns.boxplot(df['workclass'],df['hours.per.week'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize = (7,5),dpi = 100)
sns.violinplot(df['sex'],df['fnlwgt'])
plt.show()

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(df['income'],df['sex'],margins = True)
# Out:
# sex     Female   Male    All
# income
# <=50K     9592  15128  24720
# >50K      1179   6662   7841
# All      10771  21790  32561

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(df['income'],df['race'],margins = True)
# Out:
# race    Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  White    All
# income
# <=50K                  275                 763   2737    246  20699  24720
# >50K                    36                 276    387     25   7117   7841
# All                    311                1039   3124    271  27816  32561

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(df['sex'],df['occupation'])
# Out:
# occupation     ?  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# sex
# Female       841          2537             0           222             1159
# Male        1002          1233             9          3877             2907
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# sex
# Female                   65                164                550
# Male                    929               1206               1452
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# sex
# Female               1800              141            1515               76
# Male                 1495                8            2625              573
#
# occupation  Sales  Tech-support  Transport-moving
# sex
# Female       1263           348                90
# Male         2387           580              1507

# %%
pd.pivot_table(df,index = 'sex',columns = 'occupation',values = 'age').plot(kind = 'bar')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(df['income'],df['workclass'])
# Out:
# workclass     ?  Federal-gov  Local-gov  Never-worked  Private  Self-emp-inc  \
# income
# <=50K      1645          589       1476             7    17733           494
# >50K        191          371        617             0     4963           622
#
# workclass  Self-emp-not-inc  State-gov  Without-pay
# income
# <=50K                  1817        945           14
# >50K                    724        353            0

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(df['income'],df['marital.status'])
# Out:
# marital.status  Divorced  Married-AF-spouse  Married-civ-spouse  \
# income
# <=50K               3980                 13                8284
# >50K                 463                 10                6692
#
# marital.status  Married-spouse-absent  Never-married  Separated  Widowed
# income
# <=50K                             384          10192        959      908
# >50K                               34            491         66       85

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(df['income'],df['occupation'])
# Out:
# occupation     ?  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# income
# <=50K       1652          3263             8          3170             2098
# >50K         191           507             1           929             1968
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# income
# <=50K                   879               1284               1752
# >50K                    115                 86                250
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# income
# <=50K                3158              148            2281              438
# >50K                  137                1            1859              211
#
# occupation  Sales  Tech-support  Transport-moving
# income
# <=50K        2667           645              1277
# >50K          983           283               320

# %%
pd.pivot_table(df,values = 'age', index = 'income', columns = 'occupation')
# Out:
# occupation          ?  Adm-clerical  Armed-Forces  Craft-repair  \
# income
# <=50K       39.179177     35.987128         28.25     37.659621
# >50K        55.617801     43.254438         46.00     43.712594
#
# occupation  Exec-managerial  Farming-fishing  Handlers-cleaners  \
# income
# <=50K             39.609152        40.445961          31.462617
# >50K              44.898374        47.060870          42.662791
#
# occupation  Machine-op-inspct  Other-service  Priv-house-serv  Prof-specialty  \
# income
# <=50K               37.048516      34.664661        41.689189       37.942569
# >50K                42.388000      41.518248        47.000000       43.677246
#
# occupation  Protective-serv      Sales  Tech-support  Transport-moving
# income
# <=50K             37.705479  34.780277     34.355039         39.120595
# >50K              41.545024  44.336724     43.102473         44.496875
